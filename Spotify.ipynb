# %%
# !pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/252.1 kB ? eta -:--:--
#    -------------- ------------------------- 92.2/252.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 252.1/252.1 kB 3.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
spotify_cred=SpotifyClientCredentials(client_id="252f54f93218423c8a8fea404f4ce525",client_secret="57b2d195f73e4a28a2a942ddfdb10566")
sp=spotipy.Spotify(client_credentials_manager=spotify_cred)
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF?si=3a58ec60cb1b4754&nd=1&dlsi=3a8fcd396ae54619"

# %%
playlist_uri=playlist_link.split("/")[4].split("?")[0]
# Out:
# '37i9dQZEVXbMDoHDwVN2tF'

# %%
data=sp.playlist_tracks(playlist_uri)

# %%
'''data['items'][0]['track']['album'].keys()
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['total_tracks']
data['items'][0]['track']['album']['external_urls']['spotify']'''

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_dict={'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,'album_total_tracks':album_total_tracks,'album_url':album_url}
    album_list.append(album_dict)

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for _ in value['artists']:
                artist_dict={'artist_id':value['id'],'artist_name':value['name'],'external_url':value['href']}
                artist_list.append(artist_dict)

# %%
data['items']
# Out:
# [{'added_at': '2024-07-04T11:00:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
# ...

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_elements={'song_id':song_id,'song_name':song_name, 'song_duration':song_duration,'song_url':song_url,
                   'song_popularity':song_popularity,'song_popularity':song_popularity,'song_added':song_added,
                    'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_elements)

# %%
import pandas as pd

# %%
albums_df=pd.DataFrame.from_dict(album_list)

# %%
albums_df.head()
# Out:
#                  album_id            album_name album_release_date  \
# 0  5bBaoign62r1i7OV8w7mi9  Please Please Please         2024-06-06
# 1  5quMTd5zeI9yW5UDua8wS4              Espresso         2024-04-12
# 2  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT         2024-05-17
# 3  5tSQtQGkrCJx3hoQxmLgfM             Gata Only         2024-02-02
# 4  5JjnoGJyOxfSZUZtk2rRwZ           Not Like Us         2024-05-04
#
#    album_total_tracks                                          album_url
# 0                   2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 1                   1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 2                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3                   1  https://open.spotify.com/album/5tSQtQGkrCJx3ho...
# 4                   1  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...

# %%
artists_df=pd.DataFrame.from_dict(artist_list)

# %%
songs_df=pd.DataFrame.from_dict(song_list)

# %%
artists_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  5N3hjp1WNayUPZrA8kJmJP  Please Please Please
# 1  2qSkIjg1o9h3YT9RAgYN75              Espresso
# 2  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER
# 3  6XjDF6nds4DE2BBbagZol6             Gata Only
# 4  6XjDF6nds4DE2BBbagZol6             Gata Only
#
#                                         external_url
# 0  https://api.spotify.com/v1/tracks/5N3hjp1WNayU...
# 1  https://api.spotify.com/v1/tracks/2qSkIjg1o9h3...
# 2  https://api.spotify.com/v1/tracks/6dOtVTDdiauQ...
# 3  https://api.spotify.com/v1/tracks/6XjDF6nds4DE...
# 4  https://api.spotify.com/v1/tracks/6XjDF6nds4DE...

# %%
songs_df.head()
# Out:
#                   song_id             song_name  song_duration  \
# 0  5N3hjp1WNayUPZrA8kJmJP  Please Please Please         186365
# 1  2qSkIjg1o9h3YT9RAgYN75              Espresso         175459
# 2  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER         210373
# 3  6XjDF6nds4DE2BBbagZol6             Gata Only         222000
# 4  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us         274192
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/5N3hjp1WNayUPZr...               98
# 1  https://open.spotify.com/track/2qSkIjg1o9h3YT9...              100
# 2  https://open.spotify.com/track/6dOtVTDdiauQNBQ...               98
# 3  https://open.spotify.com/track/6XjDF6nds4DE2BB...               96
# 4  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...               96
#
#              song_added                album_id               artist_id
# 0  2024-07-04T11:00:58Z  5bBaoign62r1i7OV8w7mi9  74KM79TiuVKeVCqs8QtB0B
# ...

# %%
albums_df=albums_df.drop_duplicates(subset=['album_id'])

# %%
artists_df=artists_df.drop_duplicates(subset=['artist_id'])

# %%
albums_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            46 non-null     object
#  1   album_name          46 non-null     object
#  2   album_release_date  46 non-null     datetime64[ns]
#  3   album_total_tracks  46 non-null     int64
#  4   album_url           46 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.2+ KB

# %%
albums_df['album_release_date']=pd.to_datetime(albums_df['album_release_date'])

# %%
songs_df['song_added']=pd.to_datetime(songs_df['song_added'])

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_url         50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     datetime64[ns, UTC]
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
import boto3

# %%
s3=boto3.client('s3')

# %%
s3=boto3.client('s3')
    Bucket="my-spotify-etl-project"
    Key="raw_data/to_processed/"
